# %%
# install.packages("openNLP")
# install.packages("wordcloud")
# install.packages('stringr')
# install.packages('hunspell')
# install.packages('ds4psy')
# install.packages("glue")
# install.packages('textclean')
# install.packages("tm")
# install.packages("tokenizers")
# install.packages('parsedate')
# install.packages('spacyr')
# install.packages('caret')

# %%
library('stringr')
library('hunspell')
library('ds4psy')
library('glue')
library('spacyr')
library('tm')
library('dplyr',  warn.conflicts = FALSE)
library('parsedate')
library("tokenizers", warn.conflicts = FALSE)


# replacing contractions with full forms
library('textclean')
library('caret')
library("e1071")
# Out:
# Welcome to ds4psy (v0.9.0)!
#
# Loading required package: NLP
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘ggplot2’
#
#
# The following object is masked from ‘package:NLP’:
#
#     annotate
#
#
# Loading required package: lattice

# %%
# Cleaning dataset for further usage
# msa = Music Sentiment Analysis

# reading dataset
msa_dataset <- read.csv('../Datasets/msa_nju_dataset.csv')
msa_dataset = filter(msa_dataset, sentiment != "relaxed")

# saving unprocessed lyrics
# msa_dataset['unprocessed_lyrics'] = msa_dataset['lyrics']
names(msa_dataset)
# Out:
#  [1] "index"            "id"               "uri"              "title"
#  [5] "artist"           "duration_ms"      "explicit"         "track_number"
#  [9] "release_date"     "popularity"       "danceability"     "energy"
# [13] "key"              "loudness"         "speechiness"      "acousticness"
# [17] "instrumentalness" "liveness"         "valence"          "mode"
# [21] "tempo"            "raw_lyrics"       "sentiment"

# %%
# displaying dataset
head(msa_dataset[c('index','id','uri','title','artist','duration_ms','explicit','track_number','release_date','popularity','danceability','energy','key','loudness','speechiness','acousticness','instrumentalness','liveness','valence','mode','tempo','sentiment')], 5)
# Out:
#   index id                     uri
# 1 37    2VAYHSRr2Uj9lJHp87AnaP spotify:track:2VAYHSRr2Uj9lJHp87AnaP
# 2 18    4S5MU2rrPqkGYWp98vFVvj spotify:track:4S5MU2rrPqkGYWp98vFVvj
# 3 99    4MW6iAySicumcMCbScZPCG spotify:track:4MW6iAySicumcMCbScZPCG
# 4  1    05eiKEr80zHnYNpD4u8ili spotify:track:05eiKEr80zHnYNpD4u8ili
# 5 11    6COzRkOa5o0TrsVcSjJHrO spotify:track:6COzRkOa5o0TrsVcSjJHrO
#   title             artist           duration_ms explicit track_number
# 1 Ever Be           Korn             288733      True      8
# 2 Dannyboy          Youngblood Hawke 186786      False     4
# 3 Life Is Wonderful Jason Mraz       260466      False     1
# 4 Like A Song       Lenka            200173      False    10
# 5 Choose Love       Ringo Starr      188121      False     8
#   release_date popularity ⋯ key loudness speechiness acousticness
# 1 2007-07-31   33         ⋯ 0    -6.087  0.0492      1.64e-04
# 2 2013-01-01   26         ⋯ 5    -5.157  0.0508      3.58e-03
# 3 2005-07-26   40         ⋯ 8    -9.286  0.0318      1.56e-01
# 4 2008-09-23   26         ⋯ 2   -13.907  0.0328      9.78e-01
# 5 2005-06-07    9         ⋯ 2    -7.099  0.0270      3.13e-05
#   instrumentalness liveness valence mode tempo   sentiment
# 1 2.63e-01         0.2310   0.3250  1    160.053 angry
# 2 5.85e-05         0.3110   0.7330  1    129.005 happy
# 3 0.00e+00         0.0496   0.3940  0     97.944 sad
# 4 2.01e-05         0.1180   0.0874  0     95.697 sad
# 5 3.68e-02         0.3900   0.7760  1    122.017 happy

# %%
# dataset columns
column_names = colnames(msa_dataset)
column_names
# Out:
#  [1] "index"            "id"               "uri"              "title"
#  [5] "artist"           "duration_ms"      "explicit"         "track_number"
#  [9] "release_date"     "popularity"       "danceability"     "energy"
# [13] "key"              "loudness"         "speechiness"      "acousticness"
# [17] "instrumentalness" "liveness"         "valence"          "mode"
# [21] "tempo"            "raw_lyrics"       "sentiment"

# %%
# # removing X column
# msa_dataset = msa_dataset[column_names[2:length(column_names)]]
# names(msa_dataset)

# %%
# first 2 lyrics and sentments
head(msa_dataset[c('raw_lyrics', 'sentiment')], 2)
# Out:
#   raw_lyrics
# 1 [00:19.34]You're the infection my friend\n[00:23.78]Disgusting right to the end\n[00:28.47]Didn't I know it then?\n[00:33.65]I knew it, I knew it\n[00:37.34]You're basic, but hard to define\n[00:41.90]Simple yet somehow sublime\n[00:46.34]Knew you would strike again\n[00:51.59]I knew it, I knew it\n[00:54.03]You're all that's wrong\n[00:58.03]With your dumbass song\n[01:03.25]Yet that's all that you will ever be\n[01:11.13]Nothing you can do 'cause\n[01:13.01]That's all that you will ever be\n[01:23.19]Polished, you shimmer when shined\n[01:27.44]But rotten and seething inside\n[01:32.13]Everyone falls for this\n[01:37.47]I knew it, I knew it\n[01:39.66]You're all that's wrong\n[01:43.59]With your dumbass song\n[01:48.22]Yet that's all that you will ever be\n[01:55.90]Nothing you can do 'cause\n[01:57.53]That's all that you will\n[02:03.14]That's all that you will\n[02:08.28]That's all that you will ever be\n[02:17.59]\n[02:35.72]Ever be, never be, want to be god\n[02:40.03]All to be, made to be, holding the son\n[02:44.53]Throwing it, breaking it, over your grave\n[02:49.09]Sending you back to the place you once came\n[02:53.69]It must be hard to be you\n[02:57.94]Nothing's alright with you\n[03:01.06]You're all that's wrong\n[03:05.13]With your dumbass song\n[03:09.62]Yet that's all that you will ever be\n[03:17.32]Nothing you can do 'cause\n[03:18.88]That's all that you will ever be\n[03:29.31]\n[03:37.69]Ever be/never be/wannabe [Repeat]\n[03:51.74]You will never be [Repeat]\n[04:07.58]You want to be God [Repeat]\n[04:15.13]It's all God [Repeat]\n[04:22.32]It's all gone [Repeat]\n[04:30.88]我faint了....\n
# 2 [00:17.34]Too young to be scared\n[00:18.71]\n[00:19.26]Optimistic, tell the truth she don't care\n[00:22.20]\n[00:22.83]Locks her lips, she ke-ga-go ke-ga-go\n[00:26.01]She got over my head\n[00:27.82]So wake up you dreamy boy\n[00:30.76]\n[00:31.94]You're harnessing a giant\n[00:33.56]And you're painting on my wings\n[00:35.55]In red paint and my wings are feather white\n[00:38.61]\n[00:39.29]Police sirens up\n[00:40.98]So you're an angel true in a movie down my street\n[00:45.43]\n[00:46.55]Wake up, Danny boy, there's a world outside\n[00:49.92]\n[00:50.48]A world outside, a world outside\n[00:53.97]Wake up, Danny boy, there's a world outside\n[00:57.78]A world outside your window\n[01:00.46]\n[01:01.47]Wake up\n[01:02.15]\n[01:10.01]You can't force change or change your path\n[01:13.70]You just have to walk on it, the woods at night\n[01:17.31]With red walls, leisurely slow, no one sees you moving but you\n[01:24.06]\n[01:25.31]So long my friends\n[01:30.74]\n[01:32.86]I think it's time you try again\n[01:35.54]\n[01:36.85]So wake up, wake up\n[01:38.16]\n[01:38.85]Wake up, Danny boy, there's a world outside\n[01:42.53]A world outside, a world outside\n[01:46.02]Wake up, Danny boy, there's a world outside\n[01:49.83]A world outside your window\n[01:52.45]\n[01:53.70]A world outside, a world outside\n[01:57.21]Wake up, Danny boy, there's a world outside\n[02:00.96]A world outside your window\n[02:03.64]\n[02:04.51]Your window, your window\n[02:07.38]\n[02:08.44]Wake up\n[02:09.13]\n[02:15.81]Wake up\n[02:16.43]\n[02:30.66]Wake up, Danny boy, there's a world outside\n[02:34.52]A world outside, a world outside\n[02:38.02]Wake up, Danny boy, there's a world outside\n[02:41.89]A world outside your window\n[02:44.58]\n[02:46.07]A world outside, a world outside\n[02:49.43]Wake up, Danny boy, there's a world outside\n[02:53.18]A world outside your window\n[02:55.92]\n[02:56.68]Your window, your window\n
#   sentiment
# 1 angry
# 2 happy

# %% [markdown]
# # Data Preprocessing
# ##### Here, each lyric will be transformed into a format that can be used for EDA and model building.
# ### Steps:
# 1) Converting lyrics to lower case,
#
# 2) Removing lyrics divisions,
#
# 3) Correcting spellings,
#
# 4) Removing contractions,
#
# 6) Removing special characters (punctuations, periods, commas, brackets, quotes, etc) and numbers,
#
# 7) Removing extra spaces if any
#
# 8) Tokenization of words (uni-gram)

# %% [markdown]
# ### Searching for missing values

# %%
sum(is.na(msa_dataset))
# Out:
# [1] 0

# %% [markdown]
# ### Parsing date to give every date the same format

# %%
# msa_dataset = transform(msa_dataset, release_date=unlist(str_split(parsedate::parse_date(release_date), " ")[1]))

# %%
# replacing ’ with '
msa_dataset = transform(msa_dataset, lyrics=str_replace_all(raw_lyrics, "’", "\'"))

# %% [markdown]
# ### 1) Converting lyrics to lowercase

# %%
msa_dataset = transform(msa_dataset, raw_lyrics=tolower(raw_lyrics))
head(msa_dataset[c('raw_lyrics', 'sentiment')], 2)
# Out:
#   raw_lyrics
# 1 [00:19.34]you're the infection my friend\n[00:23.78]disgusting right to the end\n[00:28.47]didn't i know it then?\n[00:33.65]i knew it, i knew it\n[00:37.34]you're basic, but hard to define\n[00:41.90]simple yet somehow sublime\n[00:46.34]knew you would strike again\n[00:51.59]i knew it, i knew it\n[00:54.03]you're all that's wrong\n[00:58.03]with your dumbass song\n[01:03.25]yet that's all that you will ever be\n[01:11.13]nothing you can do 'cause\n[01:13.01]that's all that you will ever be\n[01:23.19]polished, you shimmer when shined\n[01:27.44]but rotten and seething inside\n[01:32.13]everyone falls for this\n[01:37.47]i knew it, i knew it\n[01:39.66]you're all that's wrong\n[01:43.59]with your dumbass song\n[01:48.22]yet that's all that you will ever be\n[01:55.90]nothing you can do 'cause\n[01:57.53]that's all that you will\n[02:03.14]that's all that you will\n[02:08.28]that's all that you will ever be\n[02:17.59]\n[02:35.72]ever be, never be, want to be god\n[02:40.03]all to be, made to be, holding the son\n[02:44.53]throwing it, breaking it, over your grave\n[02:49.09]sending you back to the place you once came\n[02:53.69]it must be hard to be you\n[02:57.94]nothing's alright with you\n[03:01.06]you're all that's wrong\n[03:05.13]with your dumbass song\n[03:09.62]yet that's all that you will ever be\n[03:17.32]nothing you can do 'cause\n[03:18.88]that's all that you will ever be\n[03:29.31]\n[03:37.69]ever be/never be/wannabe [repeat]\n[03:51.74]you will never be [repeat]\n[04:07.58]you want to be god [repeat]\n[04:15.13]it's all god [repeat]\n[04:22.32]it's all gone [repeat]\n[04:30.88]我faint了....\n
# 2 [00:17.34]too young to be scared\n[00:18.71]\n[00:19.26]optimistic, tell the truth she don't care\n[00:22.20]\n[00:22.83]locks her lips, she ke-ga-go ke-ga-go\n[00:26.01]she got over my head\n[00:27.82]so wake up you dreamy boy\n[00:30.76]\n[00:31.94]you're harnessing a giant\n[00:33.56]and you're painting on my wings\n[00:35.55]in red paint and my wings are feather white\n[00:38.61]\n[00:39.29]police sirens up\n[00:40.98]so you're an angel true in a movie down my street\n[00:45.43]\n[00:46.55]wake up, danny boy, there's a world outside\n[00:49.92]\n[00:50.48]a world outside, a world outside\n[00:53.97]wake up, danny boy, there's a world outside\n[00:57.78]a world outside your window\n[01:00.46]\n[01:01.47]wake up\n[01:02.15]\n[01:10.01]you can't force change or change your path\n[01:13.70]you just have to walk on it, the woods at night\n[01:17.31]with red walls, leisurely slow, no one sees you moving but you\n[01:24.06]\n[01:25.31]so long my friends\n[01:30.74]\n[01:32.86]i think it's time you try again\n[01:35.54]\n[01:36.85]so wake up, wake up\n[01:38.16]\n[01:38.85]wake up, danny boy, there's a world outside\n[01:42.53]a world outside, a world outside\n[01:46.02]wake up, danny boy, there's a world outside\n[01:49.83]a world outside your window\n[01:52.45]\n[01:53.70]a world outside, a world outside\n[01:57.21]wake up, danny boy, there's a world outside\n[02:00.96]a world outside your window\n[02:03.64]\n[02:04.51]your window, your window\n[02:07.38]\n[02:08.44]wake up\n[02:09.13]\n[02:15.81]wake up\n[02:16.43]\n[02:30.66]wake up, danny boy, there's a world outside\n[02:34.52]a world outside, a world outside\n[02:38.02]wake up, danny boy, there's a world outside\n[02:41.89]a world outside your window\n[02:44.58]\n[02:46.07]a world outside, a world outside\n[02:49.43]wake up, danny boy, there's a world outside\n[02:53.18]a world outside your window\n[02:55.92]\n[02:56.68]your window, your window\n
#   sentiment
# 1 angry
# 2 happy

# %% [markdown]
# ### 2) Removing lyrics divisions,

# %%
msa_dataset = transform(
    msa_dataset, 
    lyrics=str_replace_all(
        string=raw_lyrics, 
        pattern=r"(\[(.*?)\])", 
        replacement = " "
    )
)
head(msa_dataset[c('lyrics', 'sentiment')], 2)
# Out:
#   lyrics
# 1  you're the infection my friend\n disgusting right to the end\n didn't i know it then?\n i knew it, i knew it\n you're basic, but hard to define\n simple yet somehow sublime\n knew you would strike again\n i knew it, i knew it\n you're all that's wrong\n with your dumbass song\n yet that's all that you will ever be\n nothing you can do 'cause\n that's all that you will ever be\n polished, you shimmer when shined\n but rotten and seething inside\n everyone falls for this\n i knew it, i knew it\n you're all that's wrong\n with your dumbass song\n yet that's all that you will ever be\n nothing you can do 'cause\n that's all that you will\n that's all that you will\n that's all that you will ever be\n \n ever be, never be, want to be god\n all to be, made to be, holding the son\n throwing it, breaking it, over your grave\n sending you back to the place you once came\n it must be hard to be you\n nothing's alright with you\n you're all that's wrong\n with your dumbass song\n yet that's all that you will ever be\n nothing you can do 'cause\n that's all that you will ever be\n \n ever be/never be/wannabe  \n you will never be  \n you want to be god  \n it's all god  \n it's all gone  \n 我faint了....\n
# 2  too young to be scared\n \n optimistic, tell the truth she don't care\n \n locks her lips, she ke-ga-go ke-ga-go\n she got over my head\n so wake up you dreamy boy\n \n you're harnessing a giant\n and you're painting on my wings\n in red paint and my wings are feather white\n \n police sirens up\n so you're an angel true in a movie down my street\n \n wake up, danny boy, there's a world outside\n \n a world outside, a world outside\n wake up, danny boy, there's a world outside\n a world outside your window\n \n wake up\n \n you can't force change or change your path\n you just have to walk on it, the woods at night\n with red walls, leisurely slow, no one sees you moving but you\n \n so long my friends\n \n i think it's time you try again\n \n so wake up, wake up\n \n wake up, danny boy, there's a world outside\n a world outside, a world outside\n wake up, danny boy, there's a world outside\n a world outside your window\n \n a world outside, a world outside\n wake up, danny boy, there's a world outside\n a world outside your window\n \n your window, your window\n \n wake up\n \n wake up\n \n wake up, danny boy, there's a world outside\n a world outside, a world outside\n wake up, danny boy, there's a world outside\n a world outside your window\n \n a world outside, a world outside\n wake up, danny boy, there's a world outside\n a world outside your window\n \n your window, your window\n
#   sentiment
# 1 angry
# 2 happy

# %% [markdown]
# ### 3) Correcting spellings,

# %%
correct_spellings = function(lyrics){
    print("correcting spellings")
    # checking spelling mistakes
    bad.words = hunspell(lyrics)

    # splitting bad words to a list of words
    bad.words = text_to_words(bad.words[1])

    # removing duplicates
    bad.words = unique(bad.words)

    # getting suggestions
    suggested.words = unlist(lapply(hunspell_suggest(unique(unlist(bad.words))), function(words) words[1]))
    
    # replacing bad words with suggestions
    new_lyrics = ""
    for (index in 1:length(bad.words)){
        print(glue(r"(\b{bad.words[index]}\b)"))
        new_lyrics = str_replace_all(
            string = lyrics, 
            pattern = glue(r"(\b{bad.words[index]}\b)"), 
            replacement = suggested.words[index]
        )
    }
    return (new_lyrics)
}

# %%
# applying correct_spellings to all lyrics
msa_dataset = transform(msa_dataset, lyrics=correct_spellings(lyrics))
head(msa_dataset[c('lyrics', 'sentiment')], 2)
# Out:
# [1] "correcting spellings"
# \bc\b
# \bdumbass\b
#   lyrics
# 1  you're the infection my friend\n disgusting right to the end\n didn't i know it then?\n i knew it, i knew it\n you're basic, but hard to define\n simple yet somehow sublime\n knew you would strike again\n i knew it, i knew it\n you're all that's wrong\n with your dumb ass song\n yet that's all that you will ever be\n nothing you can do 'cause\n that's all that you will ever be\n polished, you shimmer when shined\n but rotten and seething inside\n everyone falls for this\n i knew it, i knew it\n you're all that's wrong\n with your dumb ass song\n yet that's all that you will ever be\n nothing you can do 'cause\n that's all that you will\n that's all that you will\n that's all that you will ever be\n \n ever be, never be, want to be god\n all to be, made to be, holding the son\n throwing it, breaking it, over your grave\n sending you back to the place you once came\n it must be hard to be you\n nothing's alright with you\n you're all that's wrong\n with your dumb ass song\n yet that's all that you will ever be\n nothing you can do 'cause\n that's all that you will ever be\n \n ever be/never be/wannabe  \n you will never be  \n you want to be god  \n it's all god  \n it's all gone  \n 我faint了....\n
# 2  too young to be scared\n \n optimistic, tell the truth she don't care\n \n locks her lips, she ke-ga-go ke-ga-go\n she got over my head\n so wake up you dreamy boy\n \n you're harnessing a giant\n and you're painting on my wings\n in red paint and my wings are feather white\n \n police sirens up\n so you're an angel true in a movie down my street\n \n wake up, danny boy, there's a world outside\n \n a world outside, a world outside\n wake up, danny boy, there's a world outside\n a world outside your window\n \n wake up\n \n you can't force change or change your path\n you just have to walk on it, the woods at night\n with red walls, leisurely slow, no one sees you moving but you\n \n so long my friends\n \n i think it's time you try again\n \n so wake up, wake up\n \n wake up, danny boy, there's a world outside\n a world outside, a world outside\n wake up, danny boy, there's a world outside\n a world outside your window\n \n a world outside, a world outside\n wake up, danny boy, there's a world outside\n a world outside your window\n \n your window, your window\n \n wake up\n \n wake up\n \n wake up, danny boy, there's a world outside\n a world outside, a world outside\n wake up, danny boy, there's a world outside\n a world outside your window\n \n a world outside, a world outside\n wake up, danny boy, there's a world outside\n a world outside your window\n \n your window, your window\n
#   sentiment
# 1 angry
# 2 happy

# %% [markdown]
# ### 4) Removing contractions,

# %%
# replacing all contractions with their full forms
msa_dataset = transform(msa_dataset, lyrics=replace_contraction(lyrics))
head(msa_dataset[c('lyrics', 'sentiment')], 2)
# Out:
#   lyrics
# 1  you are the infection my friend\n disgusting right to the end\n did not i know it then?\n i knew it, i knew it\n you are basic, but hard to define\n simple yet somehow sublime\n knew you would strike again\n i knew it, i knew it\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will ever be\n polished, you shimmer when shined\n but rotten and seething inside\n everyone falls for this\n i knew it, i knew it\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will\n that is all that you will\n that is all that you will ever be\n \n ever be, never be, want to be god\n all to be, made to be, holding the son\n throwing it, breaking it, over your grave\n sending you back to the place you once came\n it must be hard to be you\n nothing's alright with you\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will ever be\n \n ever be/never be/wannabe  \n you will never be  \n you want to be god  \n it is all god  \n it is all gone  \n 我faint了....\n
# 2  too young to be scared\n \n optimistic, tell the truth she do not care\n \n locks her lips, she ke-ga-go ke-ga-go\n she got over my head\n so wake up you dreamy boy\n \n you are harnessing a giant\n and you are painting on my wings\n in red paint and my wings are feather white\n \n police sirens up\n so you are an angel true in a movie down my street\n \n wake up, danny boy, there is a world outside\n \n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n wake up\n \n you can not force change or change your path\n you just have to walk on it, the woods at night\n with red walls, leisurely slow, no one sees you moving but you\n \n so long my friends\n \n i think it is time you try again\n \n so wake up, wake up\n \n wake up, danny boy, there is a world outside\n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n your window, your window\n \n wake up\n \n wake up\n \n wake up, danny boy, there is a world outside\n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n your window, your window\n
#   sentiment
# 1 angry
# 2 happy

# %% [markdown]
# ### 6) Removing special characters (punctuations, periods, commas, brackets, quotes, etc) and numbers,

# %%
# replacing any internet slags that might have slipped in to the lyrics
msa_dataset = transform(msa_dataset, lyrics=replace_internet_slang(lyrics))
head(msa_dataset[c('lyrics', 'sentiment')], 2)
# Out:
#   lyrics
# 1  you are the infection my friend\n disgusting right to the end\n did not i know it then?\n i knew it, i knew it\n you are basic, but hard to define\n simple yet somehow sublime\n knew you would strike again\n i knew it, i knew it\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will ever be\n polished, you shimmer when shined\n but rotten and seething inside\n everyone falls for this\n i knew it, i knew it\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will\n that is all that you will\n that is all that you will ever be\n \n ever be, never be, want to be god\n all to be, made to be, holding the son\n throwing it, breaking it, over your grave\n sending you back to the place you once came\n it must be hard to be you\n nothing's alright with you\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will ever be\n \n ever be/never be/wannabe  \n you will never be  \n you want to be god  \n it is all god  \n it is all gone  \n 我faint了....\n
# 2  too young to be scared\n \n optimistic, tell the truth she do not care\n \n locks her lips, she ke-ga-go ke-ga-go\n she got over my head\n so wake up you dreamy boy\n \n you are harnessing a giant\n and you are painting on my wings\n in red paint and my wings are feather white\n \n police sirens up\n so you are an angel true in a movie down my street\n \n wake up, danny boy, there is a world outside\n \n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n wake up\n \n you can not force change or change your path\n you just have to walk on it, the woods at night\n with red walls, leisurely slow, no one sees you moving but you\n \n so long my friends\n \n i think it is time you try again\n \n so wake up, wake up\n \n wake up, danny boy, there is a world outside\n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n your window, your window\n \n wake up\n \n wake up\n \n wake up, danny boy, there is a world outside\n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n your window, your window\n
#   sentiment
# 1 angry
# 2 happy

# %%
# replacing underscores with spaces
msa_dataset = transform(msa_dataset, lyrics=str_replace_all(lyrics, r"(\_?\-)", " "))
head(msa_dataset[c('lyrics', 'sentiment')], 2)
# Out:
#   lyrics
# 1  you are the infection my friend\n disgusting right to the end\n did not i know it then?\n i knew it, i knew it\n you are basic, but hard to define\n simple yet somehow sublime\n knew you would strike again\n i knew it, i knew it\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will ever be\n polished, you shimmer when shined\n but rotten and seething inside\n everyone falls for this\n i knew it, i knew it\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will\n that is all that you will\n that is all that you will ever be\n \n ever be, never be, want to be god\n all to be, made to be, holding the son\n throwing it, breaking it, over your grave\n sending you back to the place you once came\n it must be hard to be you\n nothing's alright with you\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will ever be\n \n ever be/never be/wannabe  \n you will never be  \n you want to be god  \n it is all god  \n it is all gone  \n 我faint了....\n
# 2  too young to be scared\n \n optimistic, tell the truth she do not care\n \n locks her lips, she ke ga go ke ga go\n she got over my head\n so wake up you dreamy boy\n \n you are harnessing a giant\n and you are painting on my wings\n in red paint and my wings are feather white\n \n police sirens up\n so you are an angel true in a movie down my street\n \n wake up, danny boy, there is a world outside\n \n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n wake up\n \n you can not force change or change your path\n you just have to walk on it, the woods at night\n with red walls, leisurely slow, no one sees you moving but you\n \n so long my friends\n \n i think it is time you try again\n \n so wake up, wake up\n \n wake up, danny boy, there is a world outside\n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n your window, your window\n \n wake up\n \n wake up\n \n wake up, danny boy, there is a world outside\n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n a world outside, a world outside\n wake up, danny boy, there is a world outside\n a world outside your window\n \n your window, your window\n
#   sentiment
# 1 angry
# 2 happy

# %%
msa_dataset['lyrics_with_punctuations'] = msa_dataset$lyrics

# %%
# removing all punctuations
msa_dataset = transform(msa_dataset, lyrics=tolower(removePunctuation(lyrics)))
head(msa_dataset[c('lyrics', 'sentiment')], 2)
# Out:
#   lyrics
# 1  you are the infection my friend\n disgusting right to the end\n did not i know it then\n i knew it i knew it\n you are basic but hard to define\n simple yet somehow sublime\n knew you would strike again\n i knew it i knew it\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will ever be\n polished you shimmer when shined\n but rotten and seething inside\n everyone falls for this\n i knew it i knew it\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will\n that is all that you will\n that is all that you will ever be\n \n ever be never be want to be god\n all to be made to be holding the son\n throwing it breaking it over your grave\n sending you back to the place you once came\n it must be hard to be you\n nothings alright with you\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will ever be\n \n ever benever bewannabe  \n you will never be  \n you want to be god  \n it is all god  \n it is all gone  \n 我faint了\n
# 2  too young to be scared\n \n optimistic tell the truth she do not care\n \n locks her lips she ke ga go ke ga go\n she got over my head\n so wake up you dreamy boy\n \n you are harnessing a giant\n and you are painting on my wings\n in red paint and my wings are feather white\n \n police sirens up\n so you are an angel true in a movie down my street\n \n wake up danny boy there is a world outside\n \n a world outside a world outside\n wake up danny boy there is a world outside\n a world outside your window\n \n wake up\n \n you can not force change or change your path\n you just have to walk on it the woods at night\n with red walls leisurely slow no one sees you moving but you\n \n so long my friends\n \n i think it is time you try again\n \n so wake up wake up\n \n wake up danny boy there is a world outside\n a world outside a world outside\n wake up danny boy there is a world outside\n a world outside your window\n \n a world outside a world outside\n wake up danny boy there is a world outside\n a world outside your window\n \n your window your window\n \n wake up\n \n wake up\n \n wake up danny boy there is a world outside\n a world outside a world outside\n wake up danny boy there is a world outside\n a world outside your window\n \n a world outside a world outside\n wake up danny boy there is a world outside\n a world outside your window\n \n your window your window\n
#   sentiment
# 1 angry
# 2 happy

# %%
# removing all numbers
msa_dataset = transform(msa_dataset, lyrics=str_replace_all(lyrics, r"(\d)", " "))
head(msa_dataset[c('lyrics', 'sentiment')], 2)
# Out:
#   lyrics
# 1  you are the infection my friend\n disgusting right to the end\n did not i know it then\n i knew it i knew it\n you are basic but hard to define\n simple yet somehow sublime\n knew you would strike again\n i knew it i knew it\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will ever be\n polished you shimmer when shined\n but rotten and seething inside\n everyone falls for this\n i knew it i knew it\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will\n that is all that you will\n that is all that you will ever be\n \n ever be never be want to be god\n all to be made to be holding the son\n throwing it breaking it over your grave\n sending you back to the place you once came\n it must be hard to be you\n nothings alright with you\n you are all that is wrong\n with your dumb ass song\n yet that is all that you will ever be\n nothing you can do because\n that is all that you will ever be\n \n ever benever bewannabe  \n you will never be  \n you want to be god  \n it is all god  \n it is all gone  \n 我faint了\n
# 2  too young to be scared\n \n optimistic tell the truth she do not care\n \n locks her lips she ke ga go ke ga go\n she got over my head\n so wake up you dreamy boy\n \n you are harnessing a giant\n and you are painting on my wings\n in red paint and my wings are feather white\n \n police sirens up\n so you are an angel true in a movie down my street\n \n wake up danny boy there is a world outside\n \n a world outside a world outside\n wake up danny boy there is a world outside\n a world outside your window\n \n wake up\n \n you can not force change or change your path\n you just have to walk on it the woods at night\n with red walls leisurely slow no one sees you moving but you\n \n so long my friends\n \n i think it is time you try again\n \n so wake up wake up\n \n wake up danny boy there is a world outside\n a world outside a world outside\n wake up danny boy there is a world outside\n a world outside your window\n \n a world outside a world outside\n wake up danny boy there is a world outside\n a world outside your window\n \n your window your window\n \n wake up\n \n wake up\n \n wake up danny boy there is a world outside\n a world outside a world outside\n wake up danny boy there is a world outside\n a world outside your window\n \n a world outside a world outside\n wake up danny boy there is a world outside\n a world outside your window\n \n your window your window\n
#   sentiment
# 1 angry
# 2 happy

# %% [markdown]
# ### 7) Removing extra spaces if any

# %%
# replacing all whitespace characters with one space
msa_dataset = transform(
    msa_dataset, 
    lyrics=str_replace_all(
        string=lyrics, 
        pattern=r"(\s+)", 
        replacement = " "
    )
)
head(msa_dataset[c('lyrics', 'sentiment')], 2)
# Out:
#   lyrics
# 1  you are the infection my friend disgusting right to the end did not i know it then i knew it i knew it you are basic but hard to define simple yet somehow sublime knew you would strike again i knew it i knew it you are all that is wrong with your dumb ass song yet that is all that you will ever be nothing you can do because that is all that you will ever be polished you shimmer when shined but rotten and seething inside everyone falls for this i knew it i knew it you are all that is wrong with your dumb ass song yet that is all that you will ever be nothing you can do because that is all that you will that is all that you will that is all that you will ever be ever be never be want to be god all to be made to be holding the son throwing it breaking it over your grave sending you back to the place you once came it must be hard to be you nothings alright with you you are all that is wrong with your dumb ass song yet that is all that you will ever be nothing you can do because that is all that you will ever be ever benever bewannabe you will never be you want to be god it is all god it is all gone 我faint了
# 2  too young to be scared optimistic tell the truth she do not care locks her lips she ke ga go ke ga go she got over my head so wake up you dreamy boy you are harnessing a giant and you are painting on my wings in red paint and my wings are feather white police sirens up so you are an angel true in a movie down my street wake up danny boy there is a world outside a world outside a world outside wake up danny boy there is a world outside a world outside your window wake up you can not force change or change your path you just have to walk on it the woods at night with red walls leisurely slow no one sees you moving but you so long my friends i think it is time you try again so wake up wake up wake up danny boy there is a world outside a world outside a world outside wake up danny boy there is a world outside a world outside your window a world outside a world outside wake up danny boy there is a world outside a world outside your window your window your window wake up wake up wake up danny boy there is a world outside a world outside a world outside wake up danny boy there is a world outside a world outside your window a world outside a world outside wake up danny boy there is a world outside a world outside your window your window your window
#   sentiment
# 1 angry
# 2 happy

# %% [markdown]
# ### 8) Tokenization of words (uni-gram)

# %%
# holds sentiments of each lyric
sentiments.classes = msa_dataset$sentiment
table(sentiments.classes)
# Out:
# sentiments.classes
# angry happy   sad
#   158   190   189

# %%
# # a list of vectors in which each vector is a tokenized lyrics
# # converting lyrics in batches of 100
# lyrics.tokenized = list()
# print(lyrics.tokenized)
# index = 1
# while (index <= length(msa_dataset$lyrics)){
#     lyrics.tokenized = append(
#         lyrics.tokenized, 
#         tokenize_words(
#             msa_dataset$lyrics[index]
#         )
#     )
#     index = index + 1
# }

# %%
# lyrics.tokenized[1]

# %%
length(sentiments.classes)
# Out:
# [1] 537

# %%
# length(lyrics.tokenized)

# %%
# # Tokenization of the lyrics for each class
# angry.tokenized = tokenize_words(split(msa_dataset, msa_dataset$sentiment)$angry$lyrics)
# happy.tokenized = tokenize_words(split(msa_dataset, msa_dataset$sentiment)$happy$lyrics)
# sad.tokenized = tokenize_words(split(msa_dataset, msa_dataset$sentiment)$sad$lyrics)
# # relaxed.tokenized = tokenize_words(split(msa_dataset, msa_dataset$sentiment)$relaxed$lyrics)
# length(angry.tokenized)
# length(happy.tokenized)
# length(sad.tokenized)
# # length(relaxed.tokenized)

# %% [markdown]
# ### 9) Lemmatization

# %%
# download spacy english model in terminal
# install pip3 install protobuf==3.20.0
# python3 -m spacy download en

# %%
# initializing spacyr
spacy_initialize(model = 'en_core_web_sm')
# Out:
# Finding a python executable with spaCy installed...
#
# spaCy (language model: en_core_web_sm) is installed in /usr/local/bin/python3
#
# successfully initialized (spaCy Version: 3.4.3, language model: en_core_web_sm)
#
# (python options: type = "python_executable", value = "/usr/local/bin/python3")

# %%
# fetching english stopwords
stopwords.list = stopwords(kind = "en")
print(stopwords.list[56:86])

# removing contractions from stop words because lyrics does not have stop words
stopwords.cleaned = replace_contraction(stopwords.list)
print(stopwords.cleaned[56:86])
# Out:
#  [1] "could"   "ought"   "i'm"     "you're"  "he's"    "she's"   "it's"
#  [8] "we're"   "they're" "i've"    "you've"  "we've"   "they've" "i'd"
# [15] "you'd"   "he'd"    "she'd"   "we'd"    "they'd"  "i'll"    "you'll"
# [22] "he'll"   "she'll"  "we'll"   "they'll" "isn't"   "aren't"  "wasn't"
# [29] "weren't" "hasn't"  "haven't"
#  [1] "could"      "ought"      "I am"       "you are"    "he is"
#  [6] "she is"     "it is"      "we are"     "they are"   "I have"
# [11] "you have"   "we have"    "they have"  "I would"    "you would"
# [16] "he would"   "she would"  "we would"   "they would" "I will"
# [21] "you will"   "he will"    "she will"   "we will"    "they will"
# [26] "is not"     "are not"    "was not"    "were not"   "has not"
# [31] "haven't"

# %%
# # adding stopwords
# stopwords.cleaned = append(stopwords.cleaned, c(
#     "we’ll", "never", "get", "know", "just", "now", "back", "away"
# ))
# stopwords.cleaned

# %%
# pos tagging, lematization
# Not using transform here because it combines every thing into one long string
important = c()
lemmatized_lyrics = c()
for (lyrics in msa_dataset$lyrics){
    
    features = filter(
        spacy_parse(lyrics, tag=TRUE, pos=TRUE), 
        !(pos %in% important) & (entity == "") & 
        !(lemma %in% stopwords.cleaned)
    )
    
    lemmatized_lyrics = append(
        lemmatized_lyrics, 
        paste(features$lemma, collapse = ' ')
    )
}

# %%
# creating column for lemmatization
msa_dataset['lemmatized_lyrics'] = lemmatized_lyrics
msa_dataset$lemmatized_lyrics[1]
# Out:
# [1] "  infection friend disgust right end I know I know I know basic hard define simple yet somehow sublime know strike I know I know wrong dumb ass song yet will ever nothing can will ever polish shimmer shined rotten seethe inside everyone fall I know I know wrong dumb ass song yet will ever nothing can will will will ever ever never want god make hold son throw break grave send back place come must hard nothing alright wrong dumb ass song yet will ever nothing can will ever ever benever bewannabe will never want god god go 我faint了"

# %%
# replacing all whitespace characters with one space
msa_dataset = transform(
    msa_dataset, 
    lyrics=str_replace_all(
        string=lyrics, 
        pattern=r"(\s+)", 
        replacement = " "
    )
)
head(msa_dataset[c('lyrics', 'sentiment')], 2)
# Out:
#   lyrics
# 1  you are the infection my friend disgusting right to the end did not i know it then i knew it i knew it you are basic but hard to define simple yet somehow sublime knew you would strike again i knew it i knew it you are all that is wrong with your dumb ass song yet that is all that you will ever be nothing you can do because that is all that you will ever be polished you shimmer when shined but rotten and seething inside everyone falls for this i knew it i knew it you are all that is wrong with your dumb ass song yet that is all that you will ever be nothing you can do because that is all that you will that is all that you will that is all that you will ever be ever be never be want to be god all to be made to be holding the son throwing it breaking it over your grave sending you back to the place you once came it must be hard to be you nothings alright with you you are all that is wrong with your dumb ass song yet that is all that you will ever be nothing you can do because that is all that you will ever be ever benever bewannabe you will never be you want to be god it is all god it is all gone 我faint了
# 2  too young to be scared optimistic tell the truth she do not care locks her lips she ke ga go ke ga go she got over my head so wake up you dreamy boy you are harnessing a giant and you are painting on my wings in red paint and my wings are feather white police sirens up so you are an angel true in a movie down my street wake up danny boy there is a world outside a world outside a world outside wake up danny boy there is a world outside a world outside your window wake up you can not force change or change your path you just have to walk on it the woods at night with red walls leisurely slow no one sees you moving but you so long my friends i think it is time you try again so wake up wake up wake up danny boy there is a world outside a world outside a world outside wake up danny boy there is a world outside a world outside your window a world outside a world outside wake up danny boy there is a world outside a world outside your window your window your window wake up wake up wake up danny boy there is a world outside a world outside a world outside wake up danny boy there is a world outside a world outside your window a world outside a world outside wake up danny boy there is a world outside a world outside your window your window your window
#   sentiment
# 1 angry
# 2 happy

# %% [markdown]
# ### Removing stopwords

# %%
# remove_stopwords = function(lyrics){
#     new_lyrics = lyrics
    
#     for (stopword in stopwords.cleaned){
#         new_lyrics = str_remove_all(tolower(new_lyrics), glue(r"(\b\s?{stopword}\b)"))
#     }
#     return (new_lyrics)
# }
# msa_dataset = transform(msa_dataset, lyrics_no_stopwords=remove_stopwords(lemmatized_lyrics))
# msa_dataset$lyrics_no_stopwords[2]

# %%
names(msa_dataset)
# Out:
#  [1] "index"                    "id"
#  [3] "uri"                      "title"
#  [5] "artist"                   "duration_ms"
#  [7] "explicit"                 "track_number"
#  [9] "release_date"             "popularity"
# [11] "danceability"             "energy"
# [13] "key"                      "loudness"
# [15] "speechiness"              "acousticness"
# [17] "instrumentalness"         "liveness"
# [19] "valence"                  "mode"
# [21] "tempo"                    "raw_lyrics"
# [23] "sentiment"                "lyrics"
# [25] "lyrics_with_punctuations" "lemmatized_lyrics"

# %%
# msa_dataset_cleaned = fread("dataset_with_no_stopwords.csv",  select= c("lyrics_no_stopwords", "sentiment"))
msa_dataset_cleaned = msa_dataset[c("loudness", "instrumentalness", "liveness", "valence", "tempo", "mode", "valence", "energy", "danceability", "acousticness", "lemmatized_lyrics", "sentiment")]
# msa_dataset_cleaned = msa_dataset[c("lemmatized_lyrics", "sentiment")]

head(msa_dataset_cleaned, 2)
# Out:
#   loudness instrumentalness liveness valence tempo   mode valence.1 energy
# 1 -6.087   2.63e-01         0.231    0.325   160.053 1    0.325     0.902
# 2 -5.157   5.85e-05         0.311    0.733   129.005 1    0.733     0.909
#   danceability acousticness
# 1 0.474        0.000164
# 2 0.706        0.003580
#   lemmatized_lyrics
# 1   infection friend disgust right end I know I know I know basic hard define simple yet somehow sublime know strike I know I know wrong dumb ass song yet will ever nothing can will ever polish shimmer shined rotten seethe inside everyone fall I know I know wrong dumb ass song yet will ever nothing can will will will ever ever never want god make hold son throw break grave send back place come must hard nothing alright wrong dumb ass song yet will ever nothing can will ever ever benever bewannabe will never want god god go 我faint了
# 2   young scare optimistic tell truth care lock lip ke ga go ke go get head wake dreamy boy harness giant paint wing red paint wing feather white police siren angel true movie street wake danny boy world outside world outside world outside wake danny boy world outside world outside window wake can force change change path just walk wood red wall leisurely slow one see move long friend I think time try wake wake wake danny boy world outside world outside world outside wake danny boy world outside world outside window world outside world outside wake danny boy world outside world outside window window window wake wake wake danny boy world outside world outside world outside wake danny boy world outside world outside window world outside world outside wake danny boy world outside world outside window window window
#   sentiment
# 1 angry
# 2 happy

# %% [markdown]
# ### 11) Document Term Matrix
#
# - The document term matrix is a technique of structuring text data in such a away that documents will be placed in the row and the terms of each document in the rows of the dataframe. The value of each term will be either zero or one representing the absence or presence of the term in a particular document, respectively. Each cell contains the weight of a term in a particular document. The weight of a term in a document can be determined using any of the following approaches;
# <br>
#
#    - **Binary weights:** Here, the weight of a term can only be 0 or 1 representing the abscence or prescence of the term in a document, respectively.
#    - **Term frequency:** The weight of a term corresponse to the total number of times it appears in a specify document. Here, it is assumed that the higher the frequency of a term, the more important it is.
#    - **Inverse Document Frequency:** The idea here is to associate less common terms with higher weights. This is done at the corpus level and thus describes the entire corpus and not just a document.
#     <br>
#     IDF(term) = 1 + log(N/DF(term))
#     <br>
#     where
#     <br>
#     IDF = Inverse Document Frequency
#     <br>
#     DF = Document Frequency.
#     <br>
#     DF(term) = Number of documents containing term
#     <br>
#
#   - **Term Frequecny - Inverse Document Frequecy:** This approach seeks to quantify the importance of a term in a document amongst a collection of documents.
#    <br>
#    TF-IDF(term) = TF(term) * IDF(term)
#
#    <br>
#    <br>
#    **REF**
#    <br>
#    https://medium.com/analytics-vidhya/tdm-term-document-matrix-and-dtm-document-term-matrix-8b07c58957e2

# %%
lyrics = msa_dataset_cleaned$lemmatized_lyrics

# %%
# creating a corpus of all lyrics. A corpus is simply a collection of text/documents
lyrics_corpus = Corpus(VectorSource(lyrics))
lyrics_corpus
# Out:
# <<SimpleCorpus>>
# Metadata:  corpus specific: 1, document level (indexed): 0
# Content:  documents: 537

# %%
# creating a document term matrix from lyrics corpus
lyrics_document_term_matrix = DocumentTermMatrix(lyrics_corpus, control = list(
    weighting=function(x) weightTfIdf(x, normalize = TRUE)
))
lyrics_document_term_matrix
# Out:
# Warning message in TermDocumentMatrix.SimpleCorpus(x, control):
# “custom functions are ignored”
# <<DocumentTermMatrix (documents: 537, terms: 5517)>>
# Non-/sparse entries: 34006/2928623
# Sparsity           : 99%
# Maximal term length: 48
# Weighting          : term frequency - inverse document frequency (normalized) (tf-idf)

# %%
# converting dtm to matrix
lyrics_dtm_matrix = as.matrix(lyrics_document_term_matrix)
head(lyrics_dtm_matrix, 2)
# Out:
#   alright   ass       back       basic      benever   bewannabe break
# 1 0.0492727 0.1589291 0.01959754 0.08866789 0.0996569 0.0996569 0.02867414
# 2 0.0000000 0.0000000 0.00000000 0.00000000 0.0000000 0.0000000 0.00000000
#   can         come       define     ⋯ prolly quality sel shaky slang sleeve
# 1 0.024473037 0.01421968 0.07125072 ⋯ 0      0       0   0     0     0
# 2 0.005623854 0.00000000 0.00000000 ⋯ 0      0       0   0     0     0
#   spiritual swell talib whooo
# 1 0         0     0     0
# 2 0         0     0     0

# %%
length(lyrics_dtm_matrix)
# Out:
# [1] 2962629

# %%
# combining document term matrix with their respective sentiments
msa_dataset_dtm = bind_cols(lyrics_dtm_matrix, sentiment = msa_dataset_cleaned$sentiment)
head(msa_dataset_dtm, 5)
# Out:
#   alright   ass       back       basic      benever   bewannabe break
# 1 0.0492727 0.1589291 0.01959754 0.08866789 0.0996569 0.0996569 0.02867414
# 2 0.0000000 0.0000000 0.00000000 0.00000000 0.0000000 0.0000000 0.00000000
# 3 0.0000000 0.0000000 0.00000000 0.00000000 0.0000000 0.0000000 0.00000000
# 4 0.0000000 0.0000000 0.05245224 0.00000000 0.0000000 0.0000000 0.00000000
# 5 0.0000000 0.0000000 0.00000000 0.00000000 0.0000000 0.0000000 0.00000000
#   can         come       define     ⋯ quality sel shaky slang sleeve spiritual
# 1 0.024473037 0.01421968 0.07125072 ⋯ 0       0   0     0     0      0
# 2 0.005623854 0.00000000 0.00000000 ⋯ 0       0   0     0     0      0
# 3 0.000000000 0.00000000 0.00000000 ⋯ 0       0   0     0     0      0
# 4 0.032750682 0.01902928 0.00000000 ⋯ 0       0   0     0     0      0
# 5 0.000000000 0.01540466 0.00000000 ⋯ 0       0   0     0     0      0
#   swell talib whooo sentiment
# 1 0     0     0     angry
# 2 0     0     0     happy
# 3 0     0     0     sad
# 4 0     0     0     sad
# 5 0     0     0     happy

# %%
colnames(msa_dataset_cleaned) = c("loudness_col", "instrumentalness_col", "liveness_col", "valence_col", "tempo_col", "mode_col", "valence_col", "energy_col", "danceability_col", "acousticness_col", "lyrics_no_stopwords", "sentiment")

# %%
names(msa_dataset_cleaned)
# Out:
#  [1] "loudness_col"         "instrumentalness_col" "liveness_col"
#  [4] "valence_col"          "tempo_col"            "mode_col"
#  [7] "valence_col"          "energy_col"           "danceability_col"
# [10] "acousticness_col"     "lyrics_no_stopwords"  "sentiment"

# %%
msa_dataset_dtm = bind_cols(msa_dataset_cleaned[c("mode_col", "valence_col", "energy_col", "danceability_col", "acousticness_col")], msa_dataset_dtm)

# %% [markdown]
# ### Splitting dataset
# - Here, the data is divided into two halves. One for traning our model and the other for testing/validating the peformance of our model. A greater proportion of the data goes for traning. The common proportions are 70% for traning and 30% for testing/validation.

# %%
# Creating a random vector of TRUEs and FALSEs to be used in splitting the dataset into train and test
# 70% of the dataset is set to TRUE for training and 30% to FALSE for testing
set.seed(1)
msa_split_dataset = sample(c(TRUE, FALSE), nrow(msa_dataset_dtm), replace = TRUE, prob = c(0.7, 0.3))

# %%
# train dataset
msa_train_dataset = msa_dataset_dtm[msa_split_dataset, ]
head(msa_train_dataset, 3)
# Out:
#   mode_col valence_col energy_col danceability_col acousticness_col alright
# 1 1        0.325       0.902      0.474            0.000164         0.0492727
# 2 1        0.733       0.909      0.706            0.003580         0.0000000
# 3 0        0.394       0.409      0.611            0.156000         0.0000000
#   ass       back       basic      benever   ⋯ quality sel shaky slang sleeve
# 1 0.1589291 0.01959754 0.08866789 0.0996569 ⋯ 0       0   0     0     0
# 2 0.0000000 0.00000000 0.00000000 0.0000000 ⋯ 0       0   0     0     0
# 3 0.0000000 0.00000000 0.00000000 0.0000000 ⋯ 0       0   0     0     0
#   spiritual swell talib whooo sentiment
# 1 0         0     0     0     angry
# 2 0         0     0     0     happy
# 3 0         0     0     0     sad

# %%
# test dataset
msa_test_dataset = msa_dataset_dtm[!msa_split_dataset, ]
head(msa_test_dataset, 3)
# Out:
#   mode_col valence_col energy_col danceability_col acousticness_col alright ass
# 4 0        0.0874      0.115      0.327            0.9780           0       0
# 6 1        0.8440      0.895      0.755            0.0507           0       0
# 7 0        0.6550      0.880      0.721            0.1910           0       0
#   back       basic benever ⋯ quality sel shaky slang sleeve spiritual swell
# 4 0.05245224 0     0       ⋯ 0       0   0     0     0      0         0
# 6 0.00000000 0     0       ⋯ 0       0   0     0     0      0         0
# 7 0.00000000 0     0       ⋯ 0       0   0     0     0      0         0
#   talib whooo sentiment
# 4 0     0     sad
# 6 0     0     happy
# 7 0     0     happy

# %%
table(msa_test_dataset$sentiment)
# Out:
# angry happy   sad
#    42    64    52

# %%
table(msa_train_dataset$sentiment)
# Out:
# angry happy   sad
#   116   126   137

# %%
# write.csv(msa_dataset, "dataset_with_no_stopwords.csv")

# %%
# msa_train_dataset[labels]

# %% [markdown]
# ### Model Building

# %%
labels = names(msa_train_dataset)[1 :  length(names(msa_train_dataset)) - 1]
msa_model = naiveBayes(msa_train_dataset[labels], msa_train_dataset$sentiment)

# %%
pred = predict(msa_model, msa_train_dataset[labels])

# %%
confusionMatrix(as.factor(msa_train_dataset$sentiment), pred)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction angry happy sad
#      angry    27    21  68
#      happy     0    60  66
#      sad       0     3 134
#
# Overall Statistics
#
#                Accuracy : 0.5831
#                  95% CI : (0.5317, 0.6333)
#     No Information Rate : 0.7071
#     P-Value [Acc > NIR] : 1
#
#                   Kappa : 0.3576
#
#  Mcnemar's Test P-Value : <2e-16
#
# Statistics by Class:
#
#                      Class: angry Class: happy Class: sad
# Sensitivity               1.00000       0.7143     0.5000
# Specificity               0.74716       0.7763     0.9730
# Pos Pred Value            0.23276       0.4762     0.9781
# Neg Pred Value            1.00000       0.9051     0.4463
# Prevalence                0.07124       0.2216     0.7071
# Detection Rate            0.07124       0.1583     0.3536
# Detection Prevalence      0.30607       0.3325     0.3615
# Balanced Accuracy         0.87358       0.7453     0.7365

# %%
test_pred = predict(msa_model, msa_test_dataset[labels])

# %%
confusionMatrix(as.factor(msa_test_dataset$sentiment), test_pred)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction angry happy sad
#      angry     3     8  31
#      happy     3    16  45
#      sad       0    11  41
#
# Overall Statistics
#
#                Accuracy : 0.3797
#                  95% CI : (0.3038, 0.4603)
#     No Information Rate : 0.7405
#     P-Value [Acc > NIR] : 1
#
#                   Kappa : 0.0552
#
#  Mcnemar's Test P-Value : 1.17e-11
#
# Statistics by Class:
#
#                      Class: angry Class: happy Class: sad
# Sensitivity               0.50000       0.4571     0.3504
# Specificity               0.74342       0.6098     0.7317
# Pos Pred Value            0.07143       0.2500     0.7885
# Neg Pred Value            0.97414       0.7979     0.2830
# Prevalence                0.03797       0.2215     0.7405
# Detection Rate            0.01899       0.1013     0.2595
# Detection Prevalence      0.26582       0.4051     0.3291
# Balanced Accuracy         0.62171       0.5334     0.5411

# %%
table(msa_test_dataset$sentiment)
# Out:
# angry happy   sad
#    42    64    52

# %%
library(wordcloud)
# Out:
# Loading required package: RColorBrewer

# %%
grouped_data = split(msa_dataset, msa_dataset$sentiment)

# %%
wordcloud(grouped_data$happy$lemmatized_lyrics[1:100], max.words = 40)
# Out:
# Warning message in tm_map.SimpleCorpus(corpus, tm::removePunctuation):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, function(x) tm::removeWords(x, tm::stopwords())):
# “transformation drops documents”
# Warning message in strwidth(words[i], cex = size[i], ...):
# “conversion failure on '’m' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in strwidth(words[i], cex = size[i], ...):
# “conversion failure on '’m' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in strwidth(words[i], cex = size[i], ...):
# “conversion failure on '’m' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “conversion failure on '’m' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “conversion failure on '’m' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “conversion failure on '’m' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font metrics unknown for Unicode character U+2019”
# plot without title

# %%
wordcloud(grouped_data$sad$lemmatized_lyrics[1:100], max.words = 40)
# Out:
# Warning message in tm_map.SimpleCorpus(corpus, tm::removePunctuation):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, function(x) tm::removeWords(x, tm::stopwords())):
# “transformation drops documents”
# plot without title

# %%
wordcloud(grouped_data$angry$lemmatized_lyrics[1:100], max.words = 40)
# Out:
# Warning message in tm_map.SimpleCorpus(corpus, tm::removePunctuation):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, function(x) tm::removeWords(x, tm::stopwords())):
# “transformation drops documents”
# plot without title

# %%
help(DocumentTermMatrix)
